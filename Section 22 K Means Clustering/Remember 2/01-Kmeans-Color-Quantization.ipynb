# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
image_as_array = mpimg.imread('../../DATA/palm_trees.jpg')

# %%
image_as_array
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  98],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 106],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 114],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [ 10,  10,  12],
#         [ 10,  10,  12]]], dtype=uint8)

# %%
plt.figure(figsize=(6, 6), dpi=200)
plt.imshow(image_as_array)

# %%
image_as_array.shape
# Out:
# (1401, 934, 3)

# %%
height, width, channels = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(height*width, channels)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
model
# Out:
# KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
model.cluster_centers_
# Out:
# array([[ 72.5680874 , 110.20156548, 138.04801549],
#        [  2.77464305,   2.57357751,   3.6824999 ],
#        [195.82955643, 154.51384271, 104.6629042 ],
#        [ 67.28096861,  61.79546401,  62.21314995],
#        [141.10989296, 145.10252138, 142.56103273],
#        [219.33226512, 133.67472775,  43.95732075]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[ 73, 110, 138],
#        [  3,   3,   4],
#        [196, 155, 105],
#        [ 67,  62,  62],
#        [141, 145, 143],
#        [219, 134,  44]])

# %%
quantized_image = np.reshape(rgb_codes[labels], (height, width, channels))

# %%
plt.figure(figsize=(6, 6), dpi=200)
plt.imshow(quantized_image)
