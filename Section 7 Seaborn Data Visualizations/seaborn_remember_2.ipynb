# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_path = r'F:\DataSpell\data_science_ml_learning\Section 7 Seaborn Data Visualizations\data\dm_office_sales.csv'

# %%
df = pd.read_csv(df_path)

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
sns.scatterplot(x='sales', y='salary', data=df)
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='salary', y='sales', hue='division')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='salary', y='sales', hue='work experience')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='salary', y='sales', hue='work experience', palette='coolwarm')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='salary', y='sales', size='work experience')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='salary', y='sales', data=df, s=200)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='salary', y='sales', s=200, alpha=1.0)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='salary', y='sales', style='level of education')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %% [markdown]
# # 01-Distribution-Plots
