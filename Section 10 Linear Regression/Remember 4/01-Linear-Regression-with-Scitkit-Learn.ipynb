# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'F:\DataSpell\data_science_ml_learning\DATA\Advertising.csv')

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 6))

axes[0].plot(df['TV'], df['sales'], 'o')
axes[0].set_ylabel('Sales')
axes[0].set_title('TV Spend')

axes[1].plot(df['radio'], df['sales'], 'o')
axes[1].set_ylabel('Radio spend')
axes[1].set_title('Sales')

axes[2].plot(df['newspaper'], df['sales'], 'o')
axes[2].set_ylabel('Newspaper spend')
axes[2].set_title('Sales')

plt.tight_layout()

# %%
sns.pairplot(data=df, diag_kind='kde')

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(n_jobs=-1)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
predictions = model.predict(X_test)

# %%
pd.Series(predictions)
# Out:
# 0     15.741313
# 1     19.610626
# 2     11.448889
# 3     17.008198
# 4      9.172857
# 5      7.012483
# 6     20.289925
# 7     17.299540
# 8      9.775845
# 9     19.221942
# 10    12.405032
# 11    13.892350
# 12    13.725411
# 13    21.287940
# 14    18.424566
# 15     9.981984
# 16    15.552290
# 17     7.689137
# 18     7.556150
# 19    20.403112
# 20     7.792152
# 21    18.242141
# 22    24.686319
# 23    22.821991
# 24     7.979621
# 25    12.652073
# 26    21.469259
# 27     8.052286
# 28    12.423160
# 29    12.507197
# 30    10.777578
# 31    19.244601
# 32    10.070269
# 33     6.707800
# 34    17.314921
# 35     7.767643
# 36     9.253933
# 37     8.278347
# 38    10.581056
# 39    10.635911
# 40    13.010026
# 41     9.771921
# 42    10.214699
# 43     8.045720
# 44    11.567107
# 45    10.083680
# 46     8.998066
# 47    16.253889
# 48    13.239423
# 49    20.814934
# 50    12.497274
# 51    13.966159
# 52    17.562851
# 53    11.145370
# 54    12.562615
# 55     5.508703
# 56    23.294651
# 57    12.624097
# 58    18.774000
# 59    15.187857
# dtype: float64

# %%
from sklearn.metrics import (mean_absolute_error, mean_squared_error, accuracy_score, classification_report, 
                             confusion_matrix, ConfusionMatrixDisplay)

# %%
MSE = mean_squared_error(y_test, predictions)

# %%
RMSE = np.sqrt(MSE)

# %%
MAE = mean_absolute_error(y_test, predictions)

# %%
print(f'MSE: {MSE}, RMSE: {RMSE}, MAE: {MAE}')
# Out:
# MSE: 2.2987166978863796, RMSE: 1.5161519375993884, MAE: 1.213745773614481

# %%
model.coef_
# Out:
# array([ 0.04469599,  0.1875657 , -0.00032275])

# %%
model.intercept_
# Out:
# 3.151526768070651

# %%
quartet = pd.read_csv(r'F:\DataSpell\data_science_ml_learning\DATA\anscombes_quartet1.csv')

# %%
quartet['pred_y'] = 3 + 0.5 * quartet['x']

# %%
quartet['residuals'] = quartet['y'] - quartet['pred_y']

# %%
# y = 3.00 + 0.500x
quartet['pred_y'] = 3 + 0.5 * quartet['x']
quartet['residual'] = quartet['y'] - quartet['pred_y']

sns.scatterplot(data=quartet,x='x',y='y')
sns.lineplot(data=quartet,x='x',y='pred_y',color='red')
plt.vlines(quartet['x'],quartet['y'],quartet['y']-quartet['residual'])

# %%
sns.kdeplot(data=quartet['residual'])
# Out:
# <Axes: xlabel='residual', ylabel='Density'>

# %%
sns.scatterplot(data=quartet,x='y',y='residual')
plt.axhline(y=0, color='r', linestyle='--')

# %%
quartet = pd.read_csv(r'F:\DataSpell\data_science_ml_learning\DATA\anscombes_quartet2.csv')

# %%
# y = 3.00 + 0.500x
quartet['pred_y'] = 3 + 0.5 * quartet['x']
quartet['residual'] = quartet['y'] - quartet['pred_y']

sns.scatterplot(data=quartet,x='x',y='y')
sns.lineplot(data=quartet,x='x',y='pred_y',color='red')
plt.vlines(quartet['x'],quartet['y'],quartet['y']-quartet['residual'])

# %%
sns.kdeplot(quartet['residual'])
# Out:
# <Axes: xlabel='residual', ylabel='Density'>

# %%
sns.scatterplot(data=quartet,x='y',y='residual')
plt.axhline(y=0, color='r', linestyle='--')

# %%
quartet = pd.read_csv(r'F:\DataSpell\data_science_ml_learning\DATA\anscombes_quartet4.csv')

# %%
quartet['pred_y'] = 3 + 0.5 * quartet['x']

# %%
quartet['residual'] = quartet['y'] - quartet['pred_y']

# %%
sns.scatterplot(data=quartet,x='x',y='y')
sns.lineplot(data=quartet,x='x',y='pred_y',color='red')
plt.vlines(quartet['x'],quartet['y'],quartet['y']-quartet['residual'])

# %%
sns.kdeplot(quartet['residual'])
# Out:
# <Axes: xlabel='residual', ylabel='Density'>

# %%
sns.scatterplot(data=quartet,x='y',y='residual')
plt.axhline(y=0, color='r', linestyle='--')

# %%
test_predictions = model.predict(X_test)

# %%
test_res = y_test - test_predictions

# %%
sns.scatterplot(x=y_test, y=test_res)
plt.axhline(y=0, color='r', linestyle='--')

# %%
sns.displot(test_res,bins=25,kde=True)

# %%
import scipy as sp

# %%
# Create a figure and axis to plot on
fig, ax = plt.subplots(figsize=(6,8),dpi=100)
# probplot returns the raw values if needed
# we just want to see the plot, so we assign these values to _
_ = sp.stats.probplot(test_res,plot=ax)

# %%
final_model = LinearRegression()

# %%
final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_hat = final_model.predict(X)

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(16,6))

axes[0].plot(df['TV'],df['sales'],'o')
axes[0].plot(df['TV'],y_hat,'o',color='red')
axes[0].set_ylabel("Sales")
axes[0].set_title("TV Spend")

axes[1].plot(df['radio'],df['sales'],'o')
axes[1].plot(df['radio'],y_hat,'o',color='red')
axes[1].set_title("Radio Spend")
axes[1].set_ylabel("Sales")

axes[2].plot(df['newspaper'],df['sales'],'o')
axes[2].plot(df['radio'],y_hat,'o',color='red')
axes[2].set_title("Newspaper Spend");
axes[2].set_ylabel("Sales")
plt.tight_layout();

# %%
residuals = y_hat - y

# %%
sns.scatterplot(x=y,y=residuals)
plt.axhline(y=0, color='r', linestyle='--')

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
coeff_df = pd.DataFrame(final_model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
# TV            0.045765
# radio         0.188530
# newspaper    -0.001037

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
campaign = [[149,22,12]]

# %%
final_model.predict(campaign)
# Out:
# C:\Users\Zygim\anaconda3\envs\Analytic\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.893032])

# %%
from joblib import dump, load

# %%
dump(final_model, 'sales_model.joblib')
# Out:
# ['sales_model.joblib']

# %%
loaded_model = load('sales_model.joblib')

# %%
loaded_model.predict(campaign)
# Out:
# C:\Users\Zygim\anaconda3\envs\Analytic\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.893032])
