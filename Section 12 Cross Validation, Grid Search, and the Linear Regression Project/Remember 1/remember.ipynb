# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

# %% [markdown]
# # 115. Cross Validation - Test | Train Split

# %%
df_path = Path.cwd() / '..' / '..' / 'DATA' / 'Advertising.csv'

# %%
df = pd.read_csv(df_path)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(y_test, y_pred)

# %%
print(f'MAE {MAE} MSE {MSE} RMSE {RMSE}')
# Out:
# MAE 2.1631741364394363 MSE 7.341775789034128 RMSE 37     3.834058
# 109    4.449719
# 31     3.449638
# 89     4.086563
# 66     3.082207
# 119    2.569047
# 54     4.494441
# 74     4.123106
# 145    3.209361
# 142    4.483302
# 148    3.301515
# 112    3.754997
# 174    3.391165
# 55     4.868265
# 141    4.381780
# 149    3.178050
# 25     3.464102
# 34     3.082207
# 170    2.898275
# 39     4.636809
# 172    2.756810
# 153    4.358899
# 175    5.196152
# 61     4.919350
# 65     3.049590
# 50     3.376389
# 42     4.549725
# 129    3.114482
# 179    3.549648
# 2      3.049590
# 12     3.033150
# 133    4.427189
# 90     3.346640
# 22     2.366432
# 41     4.135215
# 32     3.098387
# 125    3.255764
# 196    3.114482
# 158    2.701851
# 180    3.240370
# 16     3.535534
# 186    3.209361
# 144    3.376389
# 121    2.645751
# 80     3.435113
# 18     3.361547
# 78     2.302173
# 48     3.847077
# 4      3.591657
# 15     4.732864
# 1      3.224903
# 43     3.591657
# 102    3.847077
# 164    3.449638
# 9      3.255764
# 155    1.788854
# 36     5.039841
# 190    3.286335
# 33     4.171331
# 45     3.860052
# Name: sales, dtype: float64

# %%
model_two = Ridge(alpha=1)

# %%
model_two.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred_two = model_two.predict(X_test)

# %%
y_pred
# Out:
# array([3.8340579 , 4.44971909, 3.44963766, 4.08656335, 3.082207  ,
#        2.56904652, 4.49444101, 4.12310563, 3.20936131, 4.48330235,
#        3.3015148 , 3.75499667, 3.39116499, 4.86826458, 4.38178046,
#        3.17804972, 3.46410162, 3.082207  , 2.89827535, 4.63680925,
#        2.75680975, 4.35889894, 5.19615242, 4.91934955, 3.04959014,
#        3.3763886 , 4.54972527, 3.1144823 , 3.54964787, 3.04959014,
#        3.03315018, 4.42718872, 3.34664011, 2.36643191, 4.13521463,
#        3.09838668, 3.25576412, 3.1144823 , 2.70185122, 3.24037035,
#        3.53553391, 3.20936131, 3.3763886 , 2.64575131, 3.43511281,
#        3.36154726, 2.30217289, 3.84707681, 3.591657  , 4.73286383,
#        3.2249031 , 3.591657  , 3.84707681, 3.44963766, 3.25576412,
#        1.78885438, 5.03984127, 3.28633535, 4.17133072, 3.86005181])

# %%
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(y_test, y_pred)

# %%
print(f'MAE {MAE} MSE {MSE} RMSE {RMSE}')
# Out:
# MAE 9.766139343504694 MSE 116.55124332961752 RMSE 37     3.834058
# 109    4.449719
# 31     3.449638
# 89     4.086563
# 66     3.082207
# 119    2.569047
# 54     4.494441
# 74     4.123106
# 145    3.209361
# 142    4.483302
# 148    3.301515
# 112    3.754997
# 174    3.391165
# 55     4.868265
# 141    4.381780
# 149    3.178050
# 25     3.464102
# 34     3.082207
# 170    2.898275
# 39     4.636809
# 172    2.756810
# 153    4.358899
# 175    5.196152
# 61     4.919350
# 65     3.049590
# 50     3.376389
# 42     4.549725
# 129    3.114482
# 179    3.549648
# 2      3.049590
# 12     3.033150
# 133    4.427189
# 90     3.346640
# 22     2.366432
# 41     4.135215
# 32     3.098387
# 125    3.255764
# 196    3.114482
# 158    2.701851
# 180    3.240370
# 16     3.535534
# 186    3.209361
# 144    3.376389
# 121    2.645751
# 80     3.435113
# 18     3.361547
# 78     2.302173
# 48     3.847077
# 4      3.591657
# 15     4.732864
# 1      3.224903
# 43     3.591657
# 102    3.847077
# 164    3.449638
# 9      3.255764
# 155    1.788854
# 36     5.039841
# 190    3.286335
# 33     4.171331
# 45     3.860052
# Name: sales, dtype: float64

# %% [markdown]
# # # 116. Cross Validation - Test | Validation | Train Split

# %%
# 116. Cross Validation - Test | Validation | Train Split

# %%
df_path = Path().cwd() / '..' / '..' / 'DATA' / 'Advertising.csv'

# %%
df = pd.read_csv(df_path)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_other, y_train, y_other = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
len(df)
# Out:
# 200

# %%
len(X_train)
# Out:
# 140

# %%
len(X_other)
# Out:
# 60

# %%
X_eval, X_test, y_eval, y_test = train_test_split(X_other, y_other, test_size=0.5, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_eval = scaler.transform(X_eval)

# %%
from sklearn.linear_model import Ridge

# %%
model_one = Ridge(alpha=100)

# %%
model_one.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pred = model_one.predict(X_eval)

# %%
y_eval_pred
# Out:
# array([16.0980788 , 10.8495293 ,  8.75095421, 14.83525505, 12.55896716,
#        12.8883864 , 11.58372535, 12.01609545, 16.18778637, 10.90016204,
#        11.32616781, 17.90771073, 14.09264772, 13.79206361, 13.71636726,
#         9.87999576, 15.34908128, 13.00876939, 13.43419788, 10.85075815,
#        14.75707677, 18.83377117, 17.30158479, 15.74187916, 16.49277745,
#        19.66643199, 17.6105132 , 10.07145317, 13.64670913, 17.42108555])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mean_squared_error(y_eval_pred, y_eval)
# Out:
# 7.320101458823869

# %%
model_two = Ridge(alpha=1)

# %%
model_two.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
new_pred_eval = model_two.predict(X_eval)

# %%
mean_squared_error(new_pred_eval, y_eval)
# Out:
# 2.3837830750569853

# %%
y_final_test_pred = model_two.predict(X_test)

# %%
mean_squared_error(y_final_test_pred, y_test)
# Out:
# 2.254260083800517

# %% [markdown]
# # 117. Cross Validation - cross_val_score

# %%
df_path = Path().cwd() / '..' / '..' / 'DATA' / 'Advertising.csv'

# %%
df = pd.read_csv(df_path)

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, y_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)
# Out:
# F:\DataSpell\data_science_ml_learning\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=1)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
abs(scores.mean())
# Out:
# 3.344839296530695

# %%
model = Ridge(alpha=1)

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
abs(scores.mean())
# Out:
# 3.344839296530695

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_test_pred = model.predict(X_test)

# %%
mean_squared_error(y_final_test_pred, y_test)
# Out:
# 2.2987274289337387

# %% [markdown]
# # 119. Grid Search

# %%
df_path = Path().cwd() / '..' / '..' / 'DATA' / 'Advertising.csv'

# %%
df = pd.read_csv(df_path)

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import ElasticNet

# %%
base_elastic_net_model = ElasticNet()

# %%
param_grid = {'alpha': [0.1, 1, 5, 10, 50, 100],
              'l1_ratio': [0.1, 0.5, 0.7, 0.95, 0.99, 1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator=base_elastic_net_model, param_grid=param_grid, scoring='neg_mean_squared_error', 
                          cv=5, verbose=2)

# %%
grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=10, l1_ratio=0.99; total time=   0.0s
# [CV] END ...............................alpha=10, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=10, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=10, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=10, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=10, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.5; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.7; total time=   0.0s
# [CV] END .............................alpha=50, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.95; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=50, l1_ratio=0.99; total time=   0.0s
# [CV] END ...............................alpha=50, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=50, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=50, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=50, l1_ratio=1; total time=   0.0s
# [CV] END ...............................alpha=50, l1_ratio=1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=100, l1_ratio=0.99; total time=   0.0s
# [CV] END ..............................alpha=100, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=100, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=100, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=100, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=100, l1_ratio=1; total time=   0.0s
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.1, 1, 5, 10, 50, 100],
#                          'l1_ratio': [0.1, 0.5, 0.7, 0.95, 0.99, 1]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=5)

# %%
grid_model.best_params_
# Out:
# {'alpha': 5, 'l1_ratio': 0.5}

# %%
pd.DataFrame(grid_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.001457  5.377980e-04         0.000706        0.000402          0.1
# 1        0.001102  2.035143e-04         0.000402        0.000492          0.1
# 2        0.001202  3.988896e-04         0.000702        0.000603          0.1
# 3        0.000801  4.005043e-04         0.000903        0.000492          0.1
# 4        0.001029  5.843802e-05         0.000600        0.000490          0.1
# 5        0.001000  4.672031e-07         0.001042        0.000075          0.1
# 6        0.001100  2.015607e-04         0.000200        0.000400          1.0
# 7        0.001212  3.950526e-04         0.000600        0.000490          1.0
# 8        0.001000  1.211955e-06         0.000636        0.000524          1.0
# 9        0.001000  1.243439e-06         0.000600        0.000490          1.0
# 10       0.001003  6.852865e-06         0.000801        0.000400          1.0
# 11       0.001001  4.877743e-06         0.000503        0.000448          1.0
# 12       0.001002  4.774090e-06         0.000600        0.000490          5.0
# 13       0.001202  3.977259e-04         0.000102        0.000205          5.0
# 14       0.001002  4.247867e-06         0.000400        0.000490          5.0
# 15       0.001025  5.011593e-05         0.000600        0.000490          5.0
# 16       0.000901  1.964135e-04         0.000874        0.000458          5.0
# 17       0.000902  1.954082e-04         0.000801        0.000401          5.0
# 18       0.001116  2.306973e-04         0.000788        0.000395         10.0
# 19       0.001001  2.639456e-06         0.000800        0.000400         10.0
# 20       0.000802  4.011545e-04         0.000701        0.000602         10.0
# 21       0.000801  4.005981e-04         0.000600        0.000490         10.0
# 22       0.001200  3.996696e-04         0.000301        0.000602         10.0
# 23       0.001201  3.992606e-04         0.000502        0.000634         10.0
# 24       0.001000  2.694868e-06         0.000601        0.000490         50.0
# 25       0.001100  2.027763e-04         0.000400        0.000490         50.0
# 26       0.000601  4.911110e-04         0.000700        0.000601         50.0
# 27       0.000584  4.776897e-04         0.001223        0.000276         50.0
# 28       0.001002  2.015166e-06         0.000700        0.000399         50.0
# 29       0.000600  4.899403e-04         0.000601        0.000490         50.0
# 30       0.000800  4.000196e-04         0.000800        0.000400        100.0
# 31       0.001003  2.759895e-06         0.000399        0.000489        100.0
# 32       0.001101  2.011330e-04         0.000600        0.000490        100.0
# 33       0.000802  4.008592e-04         0.000462        0.000575        100.0
# 34       0.000902  1.989469e-04         0.001001        0.000002        100.0
# 35       0.001102  2.017643e-04         0.000601        0.000491        100.0
#
#     param_l1_ratio                            params  split0_test_score  \
# 0             0.10   {'alpha': 0.1, 'l1_ratio': 0.1}          -3.141894
# 1             0.50   {'alpha': 0.1, 'l1_ratio': 0.5}          -3.144123
# 2             0.70   {'alpha': 0.1, 'l1_ratio': 0.7}          -3.145246
# 3             0.95  {'alpha': 0.1, 'l1_ratio': 0.95}          -3.146655
# 4             0.99  {'alpha': 0.1, 'l1_ratio': 0.99}          -3.146882
# 5             1.00     {'alpha': 0.1, 'l1_ratio': 1}          -3.146938
# 6             0.10     {'alpha': 1, 'l1_ratio': 0.1}          -3.165348
# 7             0.50     {'alpha': 1, 'l1_ratio': 0.5}          -3.189539
# 8             0.70     {'alpha': 1, 'l1_ratio': 0.7}          -3.202405
# 9             0.95    {'alpha': 1, 'l1_ratio': 0.95}          -3.219212
# 10            0.99    {'alpha': 1, 'l1_ratio': 0.99}          -3.221976
# 11            1.00       {'alpha': 1, 'l1_ratio': 1}          -3.222670
# 12            0.10     {'alpha': 5, 'l1_ratio': 0.1}          -3.275715
# 13            0.50     {'alpha': 5, 'l1_ratio': 0.5}          -3.440551
# 14            0.70     {'alpha': 5, 'l1_ratio': 0.7}          -3.555582
# 15            0.95    {'alpha': 5, 'l1_ratio': 0.95}          -3.715336
# 16            0.99    {'alpha': 5, 'l1_ratio': 0.99}          -3.742580
# 17            1.00       {'alpha': 5, 'l1_ratio': 1}          -3.749464
# 18            0.10    {'alpha': 10, 'l1_ratio': 0.1}          -3.426316
# 19            0.50    {'alpha': 10, 'l1_ratio': 0.5}          -3.879504
# 20            0.70    {'alpha': 10, 'l1_ratio': 0.7}          -4.190451
# 21            0.95   {'alpha': 10, 'l1_ratio': 0.95}          -4.647153
# 22            0.99   {'alpha': 10, 'l1_ratio': 0.99}          -4.727546
# 23            1.00      {'alpha': 10, 'l1_ratio': 1}          -4.747968
# 24            0.10    {'alpha': 50, 'l1_ratio': 0.1}          -4.939023
# 25            0.50    {'alpha': 50, 'l1_ratio': 0.5}         -10.450207
# 26            0.70    {'alpha': 50, 'l1_ratio': 0.7}         -15.163178
# 27            0.95   {'alpha': 50, 'l1_ratio': 0.95}         -15.869457
# 28            0.99   {'alpha': 50, 'l1_ratio': 0.99}         -15.896121
# 29            1.00      {'alpha': 50, 'l1_ratio': 1}         -15.902946
# 30            0.10   {'alpha': 100, 'l1_ratio': 0.1}          -7.098184
# 31            0.50   {'alpha': 100, 'l1_ratio': 0.5}         -15.931853
# 32            0.70   {'alpha': 100, 'l1_ratio': 0.7}         -16.265415
# 33            0.95  {'alpha': 100, 'l1_ratio': 0.95}         -16.826869
# 34            0.99  {'alpha': 100, 'l1_ratio': 0.99}         -16.931804
# 35            1.00     {'alpha': 100, 'l1_ratio': 1}         -16.958695
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -1.620364          -5.373576          -2.241735
# 1           -1.616737          -5.371705          -2.240811
# 2           -1.614934          -5.370781          -2.240355
# 3           -1.612689          -5.369637          -2.239790
# 4           -1.612331          -5.369455          -2.239701
# 5           -1.612241          -5.369409          -2.239678
# 6           -1.601852          -5.371758          -2.237435
# 7           -1.568227          -5.356074          -2.231365
# 8           -1.552396          -5.349365          -2.229147
# 9           -1.533588          -5.342049          -2.226765
# 10          -1.530677          -5.340990          -2.226424
# 11          -1.529954          -5.340730          -2.226341
# 12          -1.529741          -5.374671          -2.228424
# 13          -1.464512          -5.416358          -2.230288
# 14          -1.444940          -5.492605          -2.241802
# 15          -1.427883          -5.597485          -2.266476
# 16          -1.425933          -5.615274          -2.271506
# 17          -1.425480          -5.619765          -2.272810
# 18          -1.477776          -5.401082          -2.232737
# 19          -1.421516          -5.699248          -2.304731
# 20          -1.424836          -5.901695          -2.384292
# 21          -1.460524          -6.195460          -2.527515
# 22          -1.469615          -6.246834          -2.555129
# 23          -1.472037          -6.259871          -2.562240
# 24          -1.521829          -6.367358          -2.672849
# 25          -3.061280          -9.963144          -5.372433
# 26          -4.759688         -12.935928          -7.999536
# 27          -6.917162         -14.983152         -10.201752
# 28          -6.953553         -15.020788         -10.243157
# 29          -6.962796         -15.030346         -10.253690
# 30          -2.081834          -7.860948          -3.723948
# 31          -7.001069         -15.069956         -10.297165
# 32          -7.424726         -15.507936         -10.786479
# 33          -8.085378         -16.190621         -11.563016
# 34          -8.204778         -16.313978         -11.704500
# 35          -8.235223         -16.345431         -11.740620
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -4.338514        -3.343217        1.366381               17
# 1           -4.332799        -3.341235        1.365993               15
# 2           -4.330008        -3.340265        1.365810               14
# 3           -4.326446        -3.339044        1.365573               13
# 4           -4.325877        -3.338849        1.365535               12
# 5           -4.325735        -3.338800        1.365525               11
# 6           -4.310519        -3.337382        1.366545               10
# 7           -4.254738        -3.319989        1.363099                7
# 8           -4.227314        -3.312125        1.361576                5
# 9           -4.193475        -3.303018        1.359911                4
# 10          -4.188106        -3.301635        1.359670                3
# 11          -4.186766        -3.301292        1.359611                2
# 12          -4.193826        -3.320475        1.369947                8
# 13          -3.944871        -3.299316        1.373163                1
# 14          -3.832276        -3.313441        1.394008                6
# 15          -3.702940        -3.342024        1.426707               16
# 16          -3.683441        -3.347747        1.432615               18
# 17          -3.678618        -3.349228        1.434120               19
# 18          -4.065105        -3.320603        1.376467                9
# 19          -3.640460        -3.389092        1.462033               20
# 20          -3.515762        -3.483407        1.535894               21
# 21          -3.445773        -3.655285        1.647363               22
# 22          -3.437460        -3.687317        1.667074               23
# 23          -3.435510        -3.695525        1.672085               24
# 24          -3.538181        -3.807848        1.698086               25
# 25          -4.137557        -6.596924        3.040654               27
# 26          -5.354337        -9.242533        4.134107               28
# 27          -7.171197       -11.028544        3.782580               29
# 28          -7.165949       -11.055914        3.788656               30
# 29          -7.164857       -11.062927        3.790174               31
# 30          -3.600218        -4.873026        2.218566               26
# 31          -7.161147       -11.092238        3.796509               32
# 32          -7.204323       -11.437776        3.855468               33
# 33          -7.457030       -12.024583        3.924557               34
# 34          -7.518253       -12.134663        3.934959               35
# 35          -7.534463       -12.162886        3.937527               36

# %%
y_pred = grid_model.predict(X_test)
# Out:
# F:\DataSpell\data_science_ml_learning\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but ElasticNet was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([3.75650605, 3.58638207, 3.39902636, 3.75615662, 3.44101774,
#        3.33313553, 3.61265946, 3.53706221, 3.23056974, 3.64230438,
#        3.6297341 , 3.4085821 , 3.29162144, 3.82208452, 3.6541172 ,
#        3.46214929, 3.31418588, 3.20111986, 3.29736573, 3.6993714 ,
#        3.38162748, 3.6930365 , 3.85736829, 3.77596178, 3.2802543 ,
#        3.27614802, 3.61599318, 3.30715522, 3.33952087, 3.68484023,
#        3.56086835, 3.64547524, 3.26280635, 3.32868174, 3.62169639,
#        3.20309202, 3.3193679 , 3.24163327, 3.57572225, 3.24743734,
#        3.60180298, 3.23250765, 3.35952461, 3.40008756, 3.4895085 ,
#        3.41253725, 3.48978496, 3.44049508, 3.35698781, 3.80017386,
#        3.6213646 , 3.34244508, 3.40121062, 3.36943261, 3.27024724,
#        3.27313021, 3.79190032, 3.63996735, 3.51033705, 3.49205629])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 124.30259037911577
